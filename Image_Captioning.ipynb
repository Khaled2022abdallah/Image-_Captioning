# %%
import warnings,logging
warnings.simplefilter('ignore')
logging.disable(logging.WARNING)

# %%
# !pip -q install transformers

# %%
from transformers import pipeline

# %% [markdown]
# Image Captioning

# %%
caption = pipeline('image-to-text')
# Out:
# config.json:   0%|          | 0.00/4.34k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/982M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/236 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/120 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/211 [00:00<?, ?B/s]

# %%
# !wget -O img2text.jpg "https://media.istockphoto.com/id/1830126474/photo/portrait-of-a-business-man-sitting-in-an-office.jpg?s=2048x2048&w=is&k=20&c=BaPWYz0zmylY0wlSCThsbOYfry_SM-NP37JD4kKQwDI="
from IPython.display import Image
Image(filename='img2text.jpg')
# Out:
# --2024-08-04 15:50:15--  https://media.istockphoto.com/id/1830126474/photo/portrait-of-a-business-man-sitting-in-an-office.jpg?s=2048x2048&w=is&k=20&c=BaPWYz0zmylY0wlSCThsbOYfry_SM-NP37JD4kKQwDI=
# Resolving media.istockphoto.com (media.istockphoto.com)... 13.35.35.30, 13.35.35.18, 13.35.35.98, ...
# Connecting to media.istockphoto.com (media.istockphoto.com)|13.35.35.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 198905 (194K) [image/jpeg]
# Saving to: ‘img2text.jpg’
#
# img2text.jpg        100%[===================>] 194.24K   673KB/s    in 0.3s
#
# 2024-08-04 15:50:16 (673 KB/s) - ‘img2text.jpg’ saved [198905/198905]

# %%
caption('img2text.jpg')
# Out:
# [{'generated_text': 'a man in a suit is sitting at a table with a laptop '}]

# %% [markdown]
# OCR

# %%
ocr = pipeline('image-to-text',model='microsoft/trocr-base-handwritten')
# Out:
# config.json:   0%|          | 0.00/4.17k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/224 [00:00<?, ?B/s]

# %%
! wget -O handwritten.jpg "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSoolxi9yWGAT5SLZShv8vVd0bz47UWRzQC19fDTeE8GmGv_Rn-PCF1pP1rrUx8kOjA4gg&usqp=CAU"
# Out:
# --2024-08-04 15:50:51--  https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSoolxi9yWGAT5SLZShv8vVd0bz47UWRzQC19fDTeE8GmGv_Rn-PCF1pP1rrUx8kOjA4gg&usqp=CAU
# Resolving encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)... 108.177.125.102, 108.177.125.113, 108.177.125.101, ...
# Connecting to encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)|108.177.125.102|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4324 (4.2K) [image/jpeg]
# Saving to: ‘handwritten.jpg’
#
# handwritten.jpg     100%[===================>]   4.22K  --.-KB/s    in 0s
#
# 2024-08-04 15:50:51 (73.9 MB/s) - ‘handwritten.jpg’ saved [4324/4324]

# %%
from IPython.display import Image
Image(filename='handwritten.jpg')

# %%
ocr('handwritten.jpg')
# Out:
# [{'generated_text': 'Hope you have done it.'}]
